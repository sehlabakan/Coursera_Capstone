# %%
import pandas as pd
import numpy as np
import requests
#from bs4 import BeautifulSoup
import os
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
import seaborn as sns

print('Done!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Done!

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    CLIENT_ID = 'T1LUMOHYFVR21KSZSVKTKIFO1DPONRPOL4PGKBLWSYTPNDNV' # your Foursquare ID
    CLIENT_SECRET = 'JBKZMRN5WS2PBXLZDUMMLCYJIDZELUNSSP3QKM51GSHXXWB0' # your Foursquare Secret
    VERSION = '20180604'
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

# %%
ny_data = get_new_york_data()
ny_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_data.shape
# Out:
# (306, 4)

# %%
clr = "dodgerblue"
ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
# queens has most neighborhoods
# prepare neighborhood list that contains italian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
italian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in ny_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    italian_resturants=venues[venues['Category']=='Italian Restaurant']   
    print('(',count,'/',len(ny_data),')','Italian Resturants in '+Neighborhood+', '+Borough+':'+str(len(italian_resturants)))
    print(row)
    for resturant_detail in italian_resturants.values.tolist():
        id, name , category=resturant_detail
        italian_rest_ny = italian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Italian Resturants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Italian Resturants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Italian Resturants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Italian Resturants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Italian Resturants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Italian Resturants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Italian Resturants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Italian Resturants in Woodlawn, Bronx:1
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Italian Resturants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Italian Resturants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Italian Resturants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Italian Resturants in Pelham Parkway, Bronx:2
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Italian Resturants in City Island, Bronx:1
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Italian Resturants in Bedford Park, Bronx:1
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Italian Resturants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Italian Resturants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Italian Resturants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Italian Resturants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Italian Resturants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Italian Resturants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Italian Resturants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Italian Resturants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Italian Resturants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Italian Resturants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Italian Resturants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Italian Resturants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Italian Resturants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Italian Resturants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Italian Resturants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Italian Resturants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Italian Resturants in Parkchester, Bronx:1
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Italian Resturants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Italian Resturants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Italian Resturants in Morris Park, Bronx:1
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Italian Resturants in Belmont, Bronx:17
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Italian Resturants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Italian Resturants in North Riverdale, Bronx:1
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Italian Resturants in Pelham Bay, Bronx:2
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Italian Resturants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Italian Resturants in Edgewater Park, Bronx:1
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Italian Resturants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Italian Resturants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Italian Resturants in Pelham Gardens, Bronx:1
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Italian Resturants in Concourse, Bronx:1
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Italian Resturants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Italian Resturants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Italian Resturants in Bay Ridge, Brooklyn:5
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Italian Resturants in Bensonhurst, Brooklyn:2
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Italian Resturants in Sunset Park, Brooklyn:1
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Italian Resturants in Greenpoint, Brooklyn:1
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Italian Resturants in Gravesend, Brooklyn:2
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Italian Resturants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Italian Resturants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Italian Resturants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Italian Resturants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Italian Resturants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Italian Resturants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Italian Resturants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Italian Resturants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Italian Resturants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Italian Resturants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Italian Resturants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Italian Resturants in Bushwick, Brooklyn:1
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Italian Resturants in Bedford Stuyvesant, Brooklyn:0
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Italian Resturants in Brooklyn Heights, Brooklyn:1
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Italian Resturants in Cobble Hill, Brooklyn:3
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Italian Resturants in Carroll Gardens, Brooklyn:8
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Italian Resturants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Italian Resturants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Italian Resturants in Fort Greene, Brooklyn:3
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 )
in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) Italian Resturants in Concourse Village, Bronx:1
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) Italian Resturants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) Italian Resturants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) Italian Resturants in Sutton Place, Manhattan:5
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) Italian Resturants in Hunters Point, Queens:3
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) Italian Resturants in Turtle Bay, Manhattan:3
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) Italian Resturants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) Italian Resturants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) Italian Resturants in Flatiron, Manhattan:3
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) Italian Resturants in Sunnyside Gardens, Queens:1
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) Italian Resturants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) Italian Resturants in Fulton Ferry, Brooklyn:1
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) Italian Resturants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) Italian Resturants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) Italian Resturants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) Italian Resturants in Dumbo, Brooklyn:1
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) Italian Resturants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) Italian Resturants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) Italian Resturants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) Italian Resturants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) Italian Resturants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) Italian Resturants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) Italian Resturants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) Italian Resturants in Prince's Bay, Staten Island:1
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) Italian Resturants in Lighthouse Hill, Staten Island:1
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) Italian Resturants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) Italian Resturants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) Italian Resturants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) Italian Resturants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) Italian Resturants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) Italian Resturants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) Italian Resturants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) Italian Resturants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) Italian Resturants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) Italian Resturants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) Italian Resturants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) Italian Resturants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) Italian Resturants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
italian_rest_ny.to_csv('italian_rest_ny_tocsv1.csv') # Save the information so far to a .csv file due to limited calls on FourSquare

# %%
italian_rest_ny = pd.read_csv('italian_rest_ny_tocsv1.csv')
italian_rest_ny.tail()
# Out:
#      Unnamed: 0        Borough       Neighborhood                        ID  \
# 230         230         Queens  Sunnyside Gardens  5699aa86498ef437b2fd7102
# 231         231       Brooklyn       Fulton Ferry  593c0d2262420b7feccc3048
# 232         232       Brooklyn              Dumbo  593c0d2262420b7feccc3048
# 233         233  Staten Island       Prince's Bay  4c091311a1b32d7f5efb96f0
# 234         234  Staten Island    Lighthouse Hill  5079ccdce4b065f1dd8155ad
#
#                                  Name
# 230                         Zio Luigi
# 231                         Cecconi's
# 232                         Cecconi's
# 233  Certo's Gourmet Foods & Caterers
# 234                        Casa verde

# %%
italian_rest_ny.shape
# Out:
# (235, 5)

# %%
italian_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color = clr)
plt.title('Italian Resturants per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Italian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
italian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color=clr)
plt.title('Italian Resturants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('Italian Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
italian_rest_ny[italian_rest_ny['Neighborhood']=='Belmont']
# Out:
#     Unnamed: 0 Borough Neighborhood                        ID  \
# 7            7   Bronx      Belmont  4acf80aef964a52025d420e3
# 8            8   Bronx      Belmont  4af71916f964a520cf0522e3
# 9            9   Bronx      Belmont  59050f51b23dfa5f6649e678
# 10          10   Bronx      Belmont  4c9b9e7b9c663704b90463fd
# 11          11   Bronx      Belmont  4bb6470cef159c7465b275f7
# 12          12   Bronx      Belmont  4aa425bef964a5208e4520e3
# 13          13   Bronx      Belmont  4af0fa29f964a52060e021e3
# 14          14   Bronx      Belmont  4b5514c4f964a5207cda27e3
# 15          15   Bronx      Belmont  4aa193d5f964a520124120e3
# 16          16   Bronx      Belmont  4b5a4c8ff964a52049bb28e3
# 17          17   Bronx      Belmont  4bc22a22920eb713bcc51b2c
# 18          18   Bronx      Belmont  4c79d294278eb713f6a05580
# 19          19   Bronx      Belmont  4cb0d382ef1b370419643e00
# 20          20   Bronx      Belmont  4bc67f1104e8b713a833362d
# 21          21   Bronx      Belmont  53ff939c498e6b601dfa3979
# 22          22   Bronx      Belmont  4b5bc595f964a520431529e3
# 23          23   Bronx      Belmont  44941e38f964a52081341fe3
#
#                                                  Name
# 7                                 Tino's Delicatessen
# 8   Michaelangelo's Coal Fired Brick Oven Pizza Re...
# 9                                Arthur Avenue Fiasco
# 10                                 Gerbasi Ristorante
# 11                                Calabria Pork Store
# 12                              Dominick's Restaurant
# 13                                Antonio's Trattoria
# 14                                             Enzo's
# 15                      Mario's Restaurant & Catering
# 16                                Emilia's Restaurant
# 17                                         Tra Di Noi
# 18                                    Cafe al Mercato
# 19              David Greco's Arthur Avenue Trattoria
# 20  Ann & Tony's - An Original Arthur Avenue Resta...
# 21                             San Gennaro Ristorante
# 22                              Pasquale Riggaletto's
# 23                                 Arthur Avenue Cafe

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
italian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in italian_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(italian_rest_ny),')','processed')
    italian_rest_stats_ny = italian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
italian_rest_stats_ny.tail()

# %%
italian_rest_stats_ny.to_csv('italian_rest_stats_ny_csv.csv') # I continue to save data to a .csv as I move through this project
italian_rest_stats_ny.shape
italian_rest_stats_ny.info()

# %%
italian_rest_stats_ny['Likes']=italian_rest_stats_ny['Likes'].astype('float64')
italian_rest_stats_ny['Tips']=italian_rest_stats_ny['Tips'].astype('float64')
italian_rest_stats_ny.info()

# %%
italian_rest_stats_ny.describe()

# %%
# Resturant with maximum Likes
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Likes'].idxmax()]

# %%
# Resturant with maximum Ratings
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Rating'].idxmax()]

# %%
# Resturant with maximum Tips
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Tips'].idxmax()]

# %%
ny_neighborhood_stats=italian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)

# %%
ny_borough_stats=italian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()

# %%
italian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot.bar(figsize=(10,5), color=clr)
plt.title('Average rating of Italian Resturants for each Borough', fontsize=20)
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,ny_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = 'Borough Boundaries.geojson'
ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)
# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_rating.html')

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
ny_geo = r'Borough Boundaries.geojson'
ny_map.choropleth(
    geo_data=ny_geo,
    data=ny_borough_stats,
    columns=['Borough', 'Average Rating'],
    key_on='feature.properties.boro_name',
    fill_color='PuBu', #'YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Average Rating'
)
# display map
# as this is huge map data , we will save it to a file
ny_map.save('borough_rating.html')
